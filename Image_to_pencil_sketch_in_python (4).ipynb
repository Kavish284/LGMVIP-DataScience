# %% [markdown]
# Step-1

# %%
from google.colab.patches import cv2_imshow

import cv2

# %% [markdown]
# step-2 importing the image

# %%
img = cv2.imread('dog.jpg')

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=474x266 at 0x7FB86B544410>

# %% [markdown]
# step-3 convert an image into grey scale

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=474x266 at 0x7FB86B4CCBD0>

# %% [markdown]
# step-4 inverting an image

# %%
img_invert = cv2.bitwise_not(img_gray)

cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=474x266 at 0x7FB86B4E2A50>

# %% [markdown]
# step-5 smoothning an image

# %%
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)

cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=474x266 at 0x7FB86B4CCB90>

# %% [markdown]
# step-6 final image

# %%
def dodgeV2(x, y):

    return cv2.divide(x, 255 - y, scale=256)

# %%
final_img = dodgeV2(img_gray, img_smoothing)

cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=474x266 at 0x7FB86B4E2C10>
